# %%
# This changes the current directory to the base saga directory - make sure to run this first!
# This is necessary to be able to import the py files and use the right directories,
# while keeping all the notebooks in their own directory.
import os
import sys

if 'saga_base_dir' not in locals():
    saga_base_dir = os.path.abspath('..')
if saga_base_dir not in sys.path:
    os.chdir(saga_base_dir)

# %%
import urllib
import requests
import webbrowser
import datetime

import numpy as np

#astropy >= v1.1 needed
from astropy import units as u
from astropy import table 
from astropy.coordinates import SkyCoord

# %matplotlib inline
from matplotlib import pyplot as plt

import targeting #from SAGA

# %% [markdown]
# The actual catalogs were downloaded using the `download_host_sqlfile.py` file from https://github.com/saga-survey/marla to the data directory below

# %%
data_dir = '../local_data/'

# %% [markdown]
# run this to *look at* the rem list in the browser

# %%
webbrowser.open(targeting._DEFAULT_TREM_URL.replace('/export?format=csv&', '#'))
# Out:
# True

# %% [markdown]
# Now save today's version

# %%
fnremlist = 'TargetRemove{}.csv'.format(datetime.datetime.now().strftime('%b%d_%Y'))

if not os.path.exists(fnremlist):
    urllib.request.urlretrieve(targeting._DEFAULT_TREM_URL, fnremlist)
fnremlist
# Out:
# 'TargetRemoveDec16_2015.csv'

# %% [markdown]
# Load the remove list as an Astropy table, and add a "row_index" to make it easier to look at in the notebook

# %%
remlist = table.Table.read(fnremlist, format='csv',data_start=3, header_start=1)
remlist.remove_column('col6') # google made a blank column for some reason?

remlist.add_column(remlist.ColumnClass(name='row_index', data=np.arange(len(remlist))), index=0)
remlist = remlist[~remlist['SDSS ID'].mask]

remlist.show_in_notebook(display_length=10)
# Out:
# &lt;Table masked=True length=393&gt;
# <table id="table4462592072-541603" class="table table-striped table-bordered table-condensed">
# <thead><tr><th>row_index</th><th>Host Name</th><th>NSA</th><th>SDSS ID</th><th>Targ_RA</th><th>Targ_Dec</th><th>comment</th></tr></thead>
# <tr><td>0</td><td>Hamlet</td><td>166035</td><td>1237662498391261226</td><td>228.38953</td><td>41.95437</td><td>--</td></tr>
# <tr><td>1</td><td>Hamlet</td><td>166035</td><td>1237662300829384725</td><td>228.778293</td><td>42.209718</td><td>--</td></tr>
# <tr><td>2</td><td>Hamlet</td><td>166035</td><td>1237662300829253660</td><td>228.373589</td><td>42.32577</td><td>--</td></tr>
# <tr><td>3</td><td>Hamlet</td><td>166035</td><td>1237662300829384730</td><td>228.75958</td><td>42.217655</td><td>--</td></tr>
# <tr><td>4</td><td>Hamlet</td><td>166035</td><td>1237662300829253654</td><td>228.368821</td><td>42.335368</td><td>--</td></tr>
# <tr><td>5</td><td>Hamlet</td><td>166035</td><td>1237662300829253651</td><td>228.374792</td><td>42.330362</td><td>--</td></tr>
# <tr><td>6</td><td>Hamlet</td><td>166035</td><td>1237662300829384720</td><td>228.763359</td><td>42.215231</td><td>--</td></tr>
# <tr><td>7</td><td>Hamlet</td><td>166035</td><td>1237662300829189130</td><td>228.234658</td><td>42.295864</td><td>--</td></tr>
# <tr><td>55</td><td>Aeneid</td><td>148734</td><td>1237652935103676433</td><td>310.0563008</td><td>-5.785524714</td><td>--</td></tr>
# <tr><td>57</td><td>Alice</td><td>140594</td><td>1237650762927570986</td><td>180.2855078</td><td>-1.441528804</td><td>--</td></tr>
# <tr><td>58</td><td>Alice</td><td>140594</td><td>1237674648854921317</td><td>179.8642061</td><td>-1.156301836</td><td>--</td></tr>
# <tr><td>59</td><td>Alice</td><td>140594</td><td>1237674649391857948</td><td>180.1293214</td><td>-0.695983535</td><td>--</td></tr>
# <tr><td>60</td><td>Alice</td><td>140594</td><td>1237674649391988842</td><td>180.3622875</td><td>-0.720470482</td><td>--</td></tr>
# <tr><td>61</td><td>Alice</td><td>140594</td><td>1237650762927702028</td><td>180.6098101</td><td>-1.488209133</td><td>--</td></tr>
# <tr><td>62</td><td>Alice</td><td>140594</td><td>1237648720693952627</td><td>180.1647985</td><td>-0.4952457719</td><td>--</td></tr>
# <tr><td>63</td><td>Alice</td><td>140594</td><td>1237650371555623210</td><td>179.881864</td><td>-1.742935915</td><td>--</td></tr>
# <tr><td>64</td><td>Alice</td><td>140594</td><td>1237674648854659340</td><td>179.3861043</td><td>-1.258124142</td><td>shred of massive galax

# %% [markdown]
# Load the catalogs of all NSA objects in the remove list and extract the flags for any of the targets that are actually in the remove list.  Also get flag-related statistics for *everything*

# %%
#for remlist comparison
tojoin = {'OBJID': [], 'FLAGS': []}

# for "all" stats
allcount = 0
all_flag_counts = {(i+1):0 for i in range(64)}
flag_masks = {(i+1):np.array(1 << i) for i in range(64)}

# have to loop over NSAIDs to efficiently load the catalogs one at a time
remlist_ids = remlist['SDSS ID']
unsaids = np.unique(remlist['NSA'])
for i, nsanum in enumerate(unsaids):
    print('On NSA#', nsanum, 'which is', i+1, 'of', len(unsaids))
    sys.stdout.flush()
    
    fn = os.path.join(data_dir, 'sql_nsa{}.fits.gz'.format(nsanum))
    try:
        tab = table.Table.read(fn)

        # find just the remove list objects' prpoerties
        tab_matched = tab[np.in1d(tab['OBJID'], remlist_ids)]
        for key, lst in tojoin.items():
            lst.extend(tab_matched[key])
            
        #extract FLAGS statstics for *all* objects
        for i, mask in flag_masks.items():
            all_flag_counts[i] += np.sum((tab['FLAGS'].astype('uint64')&mask)!=0)
        allcount += len(tab)
        
    except FileNotFoundError:
        print('Did not find', fn, 'so skipping it')
# Out:
# On NSA# 32 which is 1 of 28
# On NSA# 13927 which is 2 of 28
# On NSA# 33446 which is 3 of 28
# On NSA# 61945 which is 4 of 28
# On NSA# 61954 which is 5 of 28
# Did not find ../local_data/sql_nsa61954.fits.gz so skipping it
# On NSA# 85746 which is 6 of 28
# On NSA# 126115 which is 7 of 28
# On NSA# 129237 which is 8 of 28
# On NSA# 129387 which is 9 of 28
# On NSA# 130625 which is 10 of 28
# On NSA# 131531 which is 11 of 28
# On NSA# 132339 which is 12 of 28
# On NSA# 140594 which is 13 of 28
# On NSA# 145729 which is 14 of 28
# On NSA# 148734 which is 15 of 28
# On NSA# 149781 which is 16 of 28
# On NSA# 149977 which is 17 of 28
# On NSA# 150238 which is 18 of 28
# On NSA# 150307 which is 19 of 28
# On NSA# 150340 which is 20 of 28
# On NSA# 150578 which is 21 of 28
# On NSA# 150877 which is 22 of 28
# Did not find ../local_data/sql_nsa150877.fits.gz so skipping it
# On NSA# 150887 which is 23 of 28
# On NSA# 153017 which is 24 of 28
# On NSA# 165536 which is 25 of 28
# On NSA# 166035 which is 26 of 28
# On NSA# 166313 which is 27 of 28
# On NSA# -- which is 28 of 28
# Did not find ../local_data/sql_nsa--.fits.gz so skipping it

# %% [markdown]
# Now combine the remove list table with the set of FLAGS we got above

# %%
if 'OBJID' in tojoin:
    tojoin['SDSS ID'] = tojoin.pop('OBJID') # rename for join
remwflags = table.join(remlist, table.Table(tojoin), join_type='left')
remwflags.show_in_notebook(display_length=10)
# Out:
# &lt;Table masked=True length=420&gt;
# <table id="table4463029944-162213" class="table table-striped table-bordered table-condensed">
# <thead><tr><th>row_index</th><th>Host Name</th><th>NSA</th><th>SDSS ID</th><th>Targ_RA</th><th>Targ_Dec</th><th>comment</th><th>FLAGS</th></tr></thead>
# <tr><td>187</td><td>--</td><td>165536</td><td>123764872124891147</td><td>221.57195</td><td>-0.19887408</td><td>--</td><td>--</td></tr>
# <tr><td>159</td><td>--</td><td>145729</td><td>1237648702984553095</td><td>224.6328147</td><td>-1.079987716</td><td>part of main galaxy</td><td>68987912960</td></tr>
# <tr><td>181</td><td>--</td><td>165536</td><td>1237648703519850685</td><td>221.0636814</td><td>-0.6259872282</td><td>star spike</td><td>105622104838420</td></tr>
# <tr><td>178</td><td>--</td><td>165536</td><td>1237648703519981589</td><td>221.3734899</td><td>-0.6247009016</td><td>star spike</td><td>105587745100124</td></tr>
# <tr><td>179</td><td>--</td><td>165536</td><td>1237648703519981596</td><td>221.3687812</td><td>-0.6257746866</td><td>star spike</td><td>105656498131036</td></tr>
# <tr><td>180</td><td>--</td><td>165536</td><td>1237648703519981597</td><td>221.3682296</td><td>-0.6248161704</td><td>star spike</td><td>105622104703324</td></tr>
# <tr><td>165</td><td>--</td><td>145729</td><td>1237648703521554658</td><td>224.9393172</td><td>-0.6272479811</td><td>second part of merging galaxy</td><td>105555532321040</td></tr>
# <tr><td>177</td><td>--</td><td>165536</td><td>1237648704056787393</td><td>221.2368418</td><td>-0.3005513682</td><td>second part of merger</td><td>35253360132112</td></tr>
# <tr><td>175</td><td>--</td><td>165536</td><td>1237648704057050408</td><td>221.8626044</td><td>-0.3057260505</td><td>star spike</td><td>439804919677184</td></tr>
# <tr><td>176</td><td>--</td><td>165536</td><td>1237648704057050409</td><td>221.8638732</td><td>-0.3042778795</td><td>star spike</td><td>281543964754176</td></tr>
# <tr><td>184</td><td>--</td><td>165536</td><td>1237648704593592350</td><td>221.0445638</td><td>0.1834074187</td><td>shred</td><td>105622104313872</td></tr>
# <tr><td>204</td><td>--</td><td>13927</td><td>1237651753473999601</td><td>181.1906451</td><td>2.119739076</td><td>star spike</td><td>281543964623104</td></tr>
# <tr><td>55</td><td>Ae

# %% [markdown]
# Convert FLAGS value to how many objects have specific bits set
#
# Note that "bit #1" is the 0th bit (in python indexing)

# %%
flags = remwflags['FLAGS']
flags = flags[~flags.mask].view(np.ndarray).astype('uint64')

bitcounts = {}
for i in range(64):
    bitmask = np.array(1 << i, dtype='uint64')
    bitcounts[i+1] = np.sum((flags & bitmask) != 0)
    
bitcounttable = table.Table(data=[list(bitcounts.values()), list(bitcounts.keys())], names=['count', 'bit'])

# %% [markdown]
# Now get the description of each bit from SDSS SQL and combine that with the Counts from above

# %%
# this SQL query gets the meaning of the flags
qry = urllib.parse.urlencode({'cmd': 'SELECT * FROM PhotoFlags', 'format': 'csv'})

url = 'http://skyserver.sdss.org/dr12/en/tools/search/x_sql.aspx?' + qry
csv = urllib.request.urlopen(url).read()

# %%
names = []
descrs = []
bits = []
# now we hand-parse it to get the bit field right
rows = csv.split(b'\n')
for row in rows[2:]:  #skip the "Table1" and the header
    if row.strip() == b'':
        continue
        
    spl = row.split(b',')
    name, val = spl[:2]
    descr = b','.join(spl[2:])
    
    names.append(name)
    descrs.append(descr)
    
    intval = int(val, 0)
    for i in range(65):
        if (intval >> i)==0:
            bits.append(i)
            break
    else:
        raise ValueError('value {} doesnt seem to be valid'.format(intval))

bittable = table.Table(data=[bits, names, descrs], names=['bit', 'name', 'description'])
bittable = table.join(bittable, bitcounttable)

# %% [markdown]
# Now add some comparison statistics

# %%
bittable['frac_rem'] = bittable['count']/len(remwflags)
bittable['frac_all'] = np.array([all_flag_counts[bitnum] for bitnum in bittable['bit']])/allcount

# %%
bittable.sort('count')
bittable.reverse()
bittable.show_in_notebook(display_length=10)
# Out:
# &lt;Table length=64&gt;
# <table id="table4861113008-389073" class="table table-striped table-bordered table-condensed">
# <thead><tr><th>bit</th><th>name</th><th>description</th><th>count</th><th>frac_rem</th><th>frac_all</th></tr></thead>
# <tr><td>29</td><td>BINNED1</td><td>Object was detected in 1x1 binned image</td><td>419</td><td>0.997619047619</td><td>0.978002466211</td></tr>
# <tr><td>5</td><td>CHILD</td><td>Object is the product of an attempt to deblend a BLENDED object.</td><td>380</td><td>0.904761904762</td><td>0.322745195518</td></tr>
# <tr><td>46</td><td>DEBLENDED_AT_EDGE</td><td>&quot;An object close enough to the edge of the frame normally not deblended, is deblended anyway. Only set for objects large enough to be EDGE in all fields/strips.&quot;</td><td>380</td><td>0.904761904762</td><td>0.322769077803</td></tr>
# <tr><td>18</td><td>INTERP</td><td>Object contains one or more pixels whose values were determined by interpolation.</td><td>363</td><td>0.864285714286</td><td>0.492042812651</td></tr>
# <tr><td>37</td><td>STATIONARY</td><td>This object was consistent with being stationary.</td><td>341</td><td>0.811904761905</td><td>0.888019866162</td></tr>
# <tr><td>9</td><td>NOPETRO</td><td>No valid Petrosian radius was found for this object.</td><td>302</td><td>0.719047619048</td><td>0.79654827877</td></tr>
# <tr><td>26</td><td>DEBLENDED_AS_PSF</td><td>Deblender treated obj as PSF</td><td>274</td><td>0.652380952381</td><td>0.13368961803</td></tr>
# <tr><td>47</td><td>DEBLEND_NOPEAK</td><td>There was no detected peak within this child in at least one band.</td><td>264</td><td>0.628571428571</td><td>0.132301521155</td></tr>
# <tr><td>13</td><td>COSMIC_RAY</td><td>Contains a pixel interpreted to be part of a cosmic ray.</td><td>223</td><td>0.530952380952</td><td>0.174045317854</td></tr>
# <tr><td>49</td><td>TOO_FEW_GOOD_DETECTIONS</td><td>A child of this object had too few good detections to be deblended as moving.</td><td>161</td><td>0.383333333333</td><td>0.464396874832</td></tr>
# <tr><td>48</td><td>PSF_FLUX_INTERP</td><td>Greater than 20% of the PSF flux is from interpolated pixels.</td><td>96</td><td>0.228571428571</td><td>0.176394067446</td></tr>
# <tr><td>32</td><td>MOVED</td><td>The deblender identified this object as possibly moving.</td><td>89</td><td>0.211904761905</td><td>0.175477767543</td></tr>
# <tr><td>4</td><td>BLENDED</td><td>Object had multiple peaks detected within it; was thus a candidate to be a deblending parent.</td><td>86</td><td>0.204761904762</td><td>0.0793842269694</td></tr>
# <tr><td>7</td><td>NODEBLEND</td><td>&quot;No deblending was attempted on this object, even though it is BLENDED.&quot;</td><td>86</td><td>0.204761904762</td><td>0.0793842269694</td></tr>
# <tr><td>20</td><td>NOTCHECKED</td><td>&quot;There are pixels in the object which were not checked to see if they included a local peak, such as cores of saturated stars.&quot;</td><td>69</td><td>0.164285714286</td><td>0.0187534422171</td></tr>
# <tr><td>3</td><td>EDGE</td><td>Object is too close to edge of frame</td><td>63</td><td>0.15</td><td>0.0131420800983</td></tr>
# <tr><td>36</td><td>BAD_MOVING_FIT</td><td>Moving fit too poor to be believable.</td><td>51</td><td>0.121428571429</td><td>0.036831844346</td></tr>
# <tr><td>45</td><td>INTERP_CENTER</td><td>Object center is close to at least one interpolated pixel.</td><td>43</td><td>0.102380952381</td><td>0.134478708212</td></tr>
# <tr><td>21</td><td>SUBTRACTED</td><td>This BRIGHT object had its wings subtracted from the frame</td><td>28</td><td>0.0666666666667</td><td>0.0278175003534</td></tr>
# <tr><td>10</td><td>MANYPETRO</td><td>More than one Petrosian radius was found.</td><td>27</td><td>0.0642857142857</td><td>0.193048305576</td></tr>
# <tr><td>57</td><td>MAYBE_CR</td><td>There is reasonable suspicion that this object is actually a cosmic ray.</td><td>8</td><td>0.0190476190476</td><td>0.015382140925</td></tr>
# <tr><td>27</td><td>DEBLEND_PRUNED</td><td>At least one child was removed because its image was too similar to a supposedly different child.</td><td>7</td><td>0.0166666666667</td><td>0.0346512455343</td></tr>
# <tr><td>34</td><td>NODEBLEND_MOVING</td><td>A MOVED object that the deblender did not treat as moving.</td><td>6</td><td>0.0142857142857</td><td>0.0768224863895</td></tr>
# <tr><td>35</td><td>TOO_FEW_DETECTIONS</td><td>A child of this object was not detected in enough bands to reliably deblend as moving.</td><td>6</td><td>0.0142857142857</td><td>0.0313691372646</td></tr>
# <tr><td>30</td><td>BINNED2</td><td>&quot;Object was detected in 2x2 binned image, after unbinned detections are replaced by background.&quot;</td><td>6</td><td>0.0142857142857</td><td>0.0281552640942</td></tr>
# <tr><td>51</td><td>DEBLEND_DEGENERATE</td><td>Two or more candidate children were essentially identical; one one was retained.</td><td>4</td><td>0.00952380952381</td><td>0.000864148791508</td></tr>
# <tr><td>33</td><td>DEBLENDED_AS_MOVING</td><td>A MOVED object that the deblender treated as moving.</td><td>4</td><td>0.00952380952381</td><td>0.0151325954195</td></tr>
# <tr><td>31</td><td>BINNED4</td><td>Object was detected in 4x4 binned image</td><td>3</td><td>0.00714285714286</td><td>0.00134471884702</td></tr>
# <tr><td>38</td><td>PEAKS_TOO_CLOSE</td><td>&quot;At least some peaks within this object were too close to be deblended, thus they were merged into a single peak.&quot;</td><td>3</td><td>0.00714285714286</td><td>0.0567038547957</td></tr>
# <tr><td>61</td><td>OBJECT2_DEBLEND_PEEPHOLE</td><td>Deblend was modified by the deblender&apos;s peephole optimiser.</td><td>1</td><td>0.00238095238095</td><td>0.000323629327446</td></tr>
# <tr><td>6</td><td>PEAKCENTER</td><td>&quot;Given center is position of peak pixel, rather than based on the maximum-likelihood estimator.&quot;</td><td>1</td><td>0.00238095238095</td><td>0.00570201732197</td></tr>
# <tr><td>2</td><td>BRIGHT</td><td>&quot;Object detected in first, bright object-finding; generally r*&lt;17.5&quot;</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>19</td><td>SATURATED</td><td>Object contains one or more saturated pixels</td><td>0</td><td>0.0</td><td>0.0501274534174</td></tr>
# <tr><td>11</td><td>NOPETRO_BIG</td><td>Petrosian radius is beyond the last point in the radial profile.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>22</td><td>NOSTOKES</td><td>Object has no measured Stokes params</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>8</td><td>NOPROFILE</td><td>Object was too small or too close to the edge to estimate a radial profile.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>17</td><td>INCOMPLETE_PROFILE</td><td>Petrosian radius intersects the edge of the frame.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>16</td><td>BAD_RADIAL</td><td>Some of the points in the given radial profile have negative signal-to-noise ratio. Not a significant parameter.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>15</td><td>MANYR90</td><td>Object has more than one 90% light radius.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>14</td><td>MANYR50</td><td>Object has more than one 50% light radius.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>12</td><td>DEBLEND_TOO_MANY_PEAKS</td><td>There were more than 25 peaks in this object to deblend; deblended brightest 25.</td><td>0</td><td>0.0</td><td>9.7478713086e-07</td></tr>
# <tr><td>64</td><td>RESERVED</td><td>Not used</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>23</td><td>BADSKY</td><td>The sky level is so bad that the highest pixel in the object is very negative; far more so than a mere non-detection. No further analysis is attempted.</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>24</td><td>PETROFAINT</td><td>&quot;At least one possible Petrosian radius was rejected as the surface brightness at r_P was too low. If NOPETRO is not set, a different, acceptable Petrosian radius was found.&quot;</td><td>0</td><td>0.0</td><td>0.0</td></tr>
# <tr><td>62</td><td>GROWN_MERGED</td><td>Growing led to a merger</td><td>0</td><td>0.0</td><td>0.0</td
