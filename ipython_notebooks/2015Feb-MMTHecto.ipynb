# %%
# This changes the current directory to the base saga directory - make sure to run this first!
# This is necessary to be able to import the py files and use the right directories,
# while keeping all the notebooks in their own directory.
import os
import sys

if 'saga_base_dir' not in locals():
    saga_base_dir = os.path.abspath('..')
if saga_base_dir not in sys.path:
    os.chdir(saga_base_dir)

# %%
import hosts
import targeting
import mmthecto

from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import rcParams

rcParams['image.interpolation'] = 'none'
rcParams['figure.figsize'] = (16, 10)

# %%
DEFAULT_URL='http://skyservice.pha.jhu.edu/DR12/ImgCutout/getjpeg.aspx?ra={ra}&dec={dec}&width={w}&height={h}&opt={flags}&scale={scale}'
def view_coo(coo, flags='', baseurl=DEFAULT_URL, size=(512, 512), scale=1):
    from IPython import display
    
    if not coo.isscalar:
        raise TypeError('Can only show scalar coordinates')
    pxscale = 0.396127*scale
    url = baseurl.format(ra=coo.ra.deg, dec=coo.dec.deg, flags=flags, w=size[0], h=size[1], scale=pxscale)
    return display.Image(url=url, format='jpeg')

# %% [markdown]
# Use catalogs already-generated by marla for clean-up on Gilgamesh and new observations of NSA33446

# %%
n33446 = hosts.NSAHost(33446)
n33446incat = ascii.read('mmthecto/mmt2015a_nsa33446.dat', format='basic', names='ra,dec,objID,r,fibermag_r,rank'.split(','))
len(n33446incat)
# Out:
# 819

# %%
gilg = hosts.gilgamesh
gilgincat = ascii.read('mmthecto/mmt2015a_nsa166313.dat', format='basic', names='ra,dec,objID,r,fibermag_r,rank'.split(','))
len(gilgincat)
# Out:
# 351

# %%
gilgoutcat = mmthecto.generate_catalog(gilg, gilgincat, gilgincat['rank'])
# Out:
# Including 351 targets
# Found
#  220 Flux stars
# Found
#  403 guide stars

# %%
gilgoutcat = mmthecto.generate_catalog(gilg, gilgincat, gilgincat['rank'])

# %% [markdown]
# ## Checks for Gilgamesh

# %%
plt.hist(gilgincat['fibermag_r'],bins=100)
None

# %%
msk = gilgincat['fibermag_r'] < 20
targeting.sampled_imagelist(gilgincat['ra'][msk],gilgincat['dec'][msk],None,
                            names=['fm_r={0}-rank={1}'.format(icat['fibermag_r'],icat['rank']) for icat in gilgincat[msk]])
# Out:
# 'name ra dec\n0 233.64039611 16.1446637\n1 234.00594371 17.09853327'

# %%
msk = gilgincat['fibermag_r'] > 23
targeting.sampled_imagelist(gilgincat['ra'][msk],gilgincat['dec'][msk],None, 
                            names=['fm_r={0}-rank={1}'.format(icat['fibermag_r'],icat['rank']) for icat in gilgincat[msk]])
# Out:
# 'name ra dec\nfm_r=23.03 234.50136652 17.21812208\nfm_r=21.74 233.60317793 16.51965648\nfm_r=22.91 234.29000823 17.26043752\nfm_r=22.0 234.31137124 16.46292823\nfm_r=22.05 233.39838779 16.60953757\nfm_r=23.13 234.29767634 16.87114371\nfm_r=22.6 233.41642516 16.63012042\nfm_r=23.67 234.11891214 16.84925407\nfm_r=23.71 233.65587087 16.36848222\nfm_r=22.44 233.97332712 16.86402395\nfm_r=23.18 234.18731531 16.40353136\nfm_r=22.63 234.33906397 16.25293452\nfm_r=21.49 234.23536325 15.98562264\nfm_r=22.77 234.07420217 15.97219865\nfm_r=22.32 234.26332291 17.27423797\nfm_r=23.23 234.07580737 16.08020945\nfm_r=22.76 234.28824501 17.27400126\nfm_r=21.59 234.14031771 16.47539986\nfm_r=20.79 234.37996456 17.16445859\nfm_r=22.95 233.78462599 16.25040975\nfm_r=22.73 233.57517901 16.94078924\nfm_r=22.97 234.52654658 17.08070454\nfm_r=22.16 234.31246815 17.2963028\nfm_r=22.99 234.46991416 17.07805236\nfm_r=21.12 233.58135674 16.98083693\nfm_r=21.62 234.1084585 16.08063095\nfm_r=21.85 233.58266295 16.98305566\nfm_r=23.38 234.04337625 17.01029657\nfm_r=24.37 233.7677316 16.85905633\nfm_r=21.79 234.87400287 16.68083313\nfm_r=21.6 234.38375592 16.49930013\nfm_r=21.82 234.32801377 16.25410254\nfm_r=22.68 234.43881315 17.23958248\nfm_r=21.56 234.49088105 16.32197432\nfm_r=23.25 233.89881731 16.91860432\nfm_r=21.54 234.43329453 17.25771909\nfm_r=21.11 234.31903392 17.06525171\nfm_r=22.6 234.46255056 15.98721718\nfm_r=22.04 234.48767497 16.29280719\nfm_r=21.6 234.33675347 16.25149437\nfm_r=21.65 233.93586948 16.88448809\nfm_r=21.62 234.40955062 17.25887361\nfm_r=22.53 234.46452474 17.09115691\nfm_r=22.11 233.96896999 16.88151922\nfm_r=22.63 233.9353827 16.8896813\nfm_r=22.49 233.90385595 16.87186376\nfm_r=22.85 234.27753288 17.30726621\nfm_r=21.58 234.64347405 16.87531092\nfm_r=22.8 234.28839602 16.73544345\nfm_r=23.8 234.72218357 17.03879287\nfm_r=21.5 234.27087676 16.76153968\nfm_r=23.52 234.62081088 16.40716092'

# %% [markdown]
# ## Catalog for Gilgamesh

# %%
mskgilg = (17<gilgincat['fibermag_r'])&(gilgincat['fibermag_r'] < 22.5)
targeting.sampled_imagelist(gilgincat['ra'][mskgilg],gilgincat['dec'][mskgilg], 
                            names=['rank={0}'.format(icat['rank']) for icat in gilgincat[mskgilg]])
# Out:
# 'name ra dec\nrank=3 233.95077521 17.18707446\nrank=4 233.72931533 17.20367587\nrank=2 234.71410622 16.45531275\nrank=4 233.41578401 16.43265599\nrank=2 234.1235671 16.64334749\nrank=3 234.11274688 16.57827343\nrank=2 234.43181641 16.28517331\nrank=4 233.74933931 17.14383643\nrank=4 234.34558457 16.00935599\nrank=2 233.66187656 16.96596128\nrank=3 234.31539926 16.70779957\nrank=2 234.06127632 16.02038484\nrank=2 233.6104583 16.72836009\nrank=3 234.18611171 16.00779157\nrank=4 234.73614881 16.83626931\nrank=4 233.64349101 16.12128734\nrank=2 234.2401268 16.7832005\nrank=4 234.57097701 16.06958967\nrank=4 234.2072588 15.906533\nrank=2 234.3412443 16.24336315\nrank=4 234.32295449 15.96180559\nrank=4 233.48049699 16.56440976\nrank=4 233.76814154 16.0063567\nrank=3 234.61027598 16.78364437\nrank=2 234.14714404 16.5703683'

# %%
#note the rank+1 - that's because *flux* stars should be rank 1, but the catalog starts at rank=1
gilgoutcat = mmthecto.generate_catalog(gilg, gilgincat[mskgilg], gilgincat['rank'][mskgilg]+1, 
                                       fnout='mmthecto/{0}_feb2015.cat'.format(gilg.name),
                                       fluxfnout='mmthecto/{0}_feb2015.fluxstars'.format(gilg.name))
# Out:
# Including 226 targets
# Found
#  220 Flux stars
# Found
#  403 guide stars

# %% [markdown]
# ## Checks for NSA33446

# %%
plt.hist(n33446incat['fibermag_r'],bins=100)
None

# %%
msk = n33446incat['fibermag_r'] < 18
targeting.sampled_imagelist(n33446incat['ra'][msk],n33446incat['dec'][msk],None,
                            names=['fm_r={0}-rank={1}'.format(icat['fibermag_r'],icat['rank']) for icat in n33446incat[msk]])
# Out:
# 'name ra dec\nfm_r=14.83-rank=3 123.3839687 36.03845282\nfm_r=17.73-rank=3 123.39090837 36.3042963\nfm_r=16.08-rank=3 123.05846921 36.34474181\nfm_r=17.02-rank=3 123.00744825 36.2927799'

# %%
msk = n33446incat['fibermag_r'] > 22
targeting.sampled_imagelist(n33446incat['ra'][msk],n33446incat['dec'][msk],None, 
                            names=['fm_r={0}-rank={1}'.format(icat['fibermag_r'],icat['rank']) for icat in n33446incat[msk]])
# Out:
# 'name ra dec\nfm_r=23.19-rank=3 123.43213637 36.3006063\nfm_r=23.53-rank=2 123.52955056 36.15377764\nfm_r=22.45-rank=2 122.78515361 36.11380404\nfm_r=22.38-rank=2 123.63528335 35.96599133\nfm_r=22.72-rank=2 123.29088118 36.24562159\nfm_r=23.09-rank=2 123.48682187 36.16937008\nfm_r=22.57-rank=2 123.41980634 36.12805611\nfm_r=22.23-rank=2 123.27644481 36.24773213\nfm_r=22.89-rank=2 123.54021139 36.57568357\nfm_r=23.18-rank=2 123.11969531 36.11371874\nfm_r=22.42-rank=2 123.67282444 36.02110179\nfm_r=23.23-rank=2 123.13915817 36.31116965\nfm_r=22.17-rank=2 122.75314912 36.22124619\nfm_r=22.76-rank=2 123.26544225 36.23202648\nfm_r=24.81-rank=2 123.49246674 36.10555653\nfm_r=22.74-rank=2 123.266749 36.25639195\nfm_r=23.18-rank=2 123.33065079 35.83287584\nfm_r=24.92-rank=2 122.81918505 36.32436224\nfm_r=22.7-rank=2 123.45053656 36.18559928\nfm_r=23.04-rank=2 123.27876296 36.24871602\nfm_r=22.54-rank=2 123.44263957 36.11265853\nfm_r=23.05-rank=2 123.37551407 35.84298387\nfm_r=22.9-rank=2 123.61030599 36.09722511\nfm_r=22.95-rank=3 123.7819697 36.17209149\nfm_r=22.06-rank=2 123.36150064 36.42578982\nfm_r=22.75-rank=2 122.70103592 36.36364306\nfm_r=22.02-rank=2 122.98543835 35.91914983\nfm_r=22.6-rank=2 123.35931667 35.88958424\nfm_r=22.49-rank=2 122.77688468 36.35439924\nfm_r=22.01-rank=2 123.00565552 36.29169182\nfm_r=23.62-rank=2 123.25488112 36.23060866\nfm_r=22.8-rank=2 122.68212348 36.22877153\nfm_r=24.8-rank=2 123.80094975 36.27392939\nfm_r=22.64-rank=2 123.53969958 36.57799689\nfm_r=23.05-rank=2 123.49024153 36.16620168\nfm_r=22.07-rank=2 123.72094719 36.21297787\nfm_r=23.36-rank=2 123.15317472 36.64679306\nfm_r=23.01-rank=2 123.44912291 35.89557667\nfm_r=22.66-rank=2 123.55243926 36.56608607\nfm_r=24.02-rank=2 123.45299611 35.86860303\nfm_r=22.2-rank=2 123.04425715 35.97044944\nfm_r=22.95-rank=2 123.44543236 35.89463217\nfm_r=22.88-rank=2 122.97884572 36.06098997\nfm_r=22.39-rank=2 123.39097161 35.82809423\nfm_r=23.4-rank=2 123.70664864 36.06760491\nfm_r=23.49-rank=2 122.97264072 36.17589404\nfm_r=23.31-rank=2 123.62974289 36.08029679\nfm_r=22.73-rank=2 123.5282762 36.58299952\nfm_r=22.48-rank=2 122.82489372 36.08650465\nfm_r=22.78-rank=2 122.83296789 36.39241824\nfm_r=22.08-rank=2 123.24007283 36.05048222\nfm_r=22.65-rank=2 123.6965473 36.44530752\nfm_r=23.0-rank=2 122.96975561 36.27925795\nfm_r=22.62-rank=2 123.27928648 36.10590664\nfm_r=22.61-rank=2 122.69934657 36.26896874\nfm_r=23.1-rank=3 123.67255576 36.13780726\nfm_r=22.19-rank=3 122.92507338 36.50493981\nfm_r=22.8-rank=2 123.64521986 36.27956029\nfm_r=23.64-rank=2 123.53090754 36.58107496\nfm_r=22.75-rank=2 122.74693571 36.08479101\nfm_r=22.01-rank=3 123.44595106 36.41288822\nfm_r=22.46-rank=3 122.89196569 36.53398497\nfm_r=22.9-rank=2 123.59317783 36.22418436\nfm_r=22.27-rank=2 123.2144806 35.94929559\nfm_r=22.17-rank=2 123.29660765 36.16786692\nfm_r=22.09-rank=2 122.73854072 36.37765647\nfm_r=22.66-rank=2 123.330549 36.36767785\nfm_r=22.26-rank=2 122.74367704 36.38512034\nfm_r=22.19-rank=2 123.45162713 36.1903297\nfm_r=22.96-rank=2 123.53963477 36.248336\nfm_r=22.12-rank=2 122.93256126 36.556904\nfm_r=22.52-rank=2 123.49243687 36.12865178\nfm_r=22.95-rank=2 123.48530137 36.19205097\nfm_r=23.32-rank=2 123.46468728 36.21245256\nfm_r=22.99-rank=2 123.54062814 36.57038705\nfm_r=22.87-rank=2 123.53659265 36.57429693\nfm_r=22.26-rank=3 122.97089523 36.05262532\nfm_r=22.71-rank=2 123.26051196 36.23423994\nfm_r=22.65-rank=2 123.54228715 36.57193455\nfm_r=22.12-rank=2 123.58685902 36.41610225\nfm_r=23.05-rank=2 123.76778398 36.14139528\nfm_r=22.59-rank=2 122.74700838 36.41495634\nfm_r=24.28-rank=2 123.04771514 36.56592981\nfm_r=23.98-rank=2 123.12558395 36.69617886\nfm_r=22.29-rank=2 122.89931757 36.192094\nfm_r=22.24-rank=2 123.72452487 36.41786088\nfm_r=22.88-rank=2 122.68869053 36.23691442\nfm_r=22.11-rank=3 122.92123997 36.5002124\nfm_r=22.39-rank=2 123.00014272 36.36307599'

# %% [markdown]
# ## Catalog for NSA33446

# %%
msk33446 = (17<n33446incat['fibermag_r'])&(n33446incat['fibermag_r'] < 22.5)
targeting.sampled_imagelist(n33446incat['ra'][msk33446],n33446incat['dec'][msk33446], 
                            names=['rank={0}'.format(icat['rank']) for icat in n33446incat[msk33446]])
# Out:
# 'name ra dec\nrank=3 122.99209228 36.20804523\nrank=2 122.82489372 36.08650465\nrank=2 123.53475798 36.26654529\nrank=2 122.95452803 36.24597756\nrank=2 122.96437986 35.90985155\nrank=2 123.06096907 35.86305374\nrank=3 123.03745447 36.23144032\nrank=2 122.9533265 36.25002652\nrank=3 123.15410839 36.30604957\nrank=2 123.06343302 35.94494721\nrank=3 122.92153666 36.06999095\nrank=3 123.62294506 36.11947787\nrank=3 123.44346598 35.93171346\nrank=3 123.55356292 36.36761315\nrank=3 123.59534067 36.52186599\nrank=3 122.86497907 36.00788091\nrank=3 123.05760494 35.93164635\nrank=3 123.1318013 36.09079282\nrank=3 122.9674854 36.53054916\nrank=3 123.5157501 36.39600359\nrank=3 123.42579215 35.82801884\nrank=2 122.78856187 36.00279122\nrank=2 123.09225971 36.55486132\nrank=3 123.63229526 36.46254133\nrank=3 123.02793719 35.86271424'

# %%
#note the rank+1 - that's because *flux* stars should be rank 1, but the catalog starts at rank=1
n33446outcat = mmthecto.generate_catalog(n33446, n33446incat[msk33446], n33446incat['rank'][msk33446]+1,
                                         repeatflux=2, removefluxdistance=1*u.arcmin,
                                         fnout='mmthecto/{0}_feb2015.cat'.format(n33446.name),
                                         fluxfnout='mmthecto/{0}_feb2015.fluxstars'.format(n33446.name))
# Out:
# Including 757 targets
# Found
#  145 Flux stars
# Removing
#  7 Flux stars too close to program stars
# Found
#  1241 guide stars
