# %%
for module in ['hosts', 'targeting', 'mmthecto']:
    if module in globals():
        reload(globals()[module])
    else:
        globals()[module] = __import__(module)
g = targeting.get_gama() #re-caches the gama catalo

#TRY TO AVOID DEC 33
#plan : ONE OR TWO HOSTS DEPENDING HOW DEEP WE WANT,

# %%
hs=hosts.load_all_hosts()
hi=hs[hs.keys()[0]]

# %%
ras = array([hs[k].ra/15. for k in hs])
decs = array([hs[k].dec for k in hs])
bs = array([hs[k].b for k in hs])
fovrad = array([hs[k].distmpc*radians(.5)*1000 for k in hs])
sorti = argsort(ras)
ras = ras[sorti]
decs = decs[sorti]
bs = decs[sorti]
fovrad = fovrad[sorti]
nsaids = array([hs[k].nsaid for k in hs])[sorti]
ks = array(hs.keys())[sorti]
nsatok = dict([(hs[k].nsaid,k) for k in hs])
#this generates an RA-ordered list of  targets - want third column to be ~1 and dec to be nearish 33 (but not too close)
zip(ras,decs,fovrad/300.,nsaids)
# Out:
# [(0.084828578434479038, -7.0933808104363774, 1.5836335129870567, 126157),
#  (0.57965602055496401, -8.3964449227422975, 0.62489439470384878, 127226),
#  (0.72440225226363242, -0.12494100366458162, 1.7004951104655825, 5916),
#  (0.82393116912089137, -1.7712327659778695, 1.597980321600829, 127782),
#  (1.3332214206724984, 14.786226831189444, 1.6609123987934831, 129140),
#  (1.4010850269086064, 12.917462362059318, 1.0767796957910605, 129387),
#  (1.4092578592606009, 3.8006638381532287, 0.87770622024569112, 129431),
#  (2.149647740176917, -7.0589262045450676, 1.6012027791703523, 131295),
#  (2.1607208870426118, -10.146168560091775, 1.5553854982345106, 23274),
#  (2.3601329144562424, -5.5212705544346434, 0.91452585565370514, 155005),
#  (2.5861356961411679, 20.851379314918734, 1.7504572371430569, 132273),
#  (2.7760965024288002, -0.24713745138021195, 1.1118089584342268, 155204),
#  (3.0663775175920849, 43.398429640241126, 1.203949389998402, 133120),
#  (3.3684885748521785, -15.399928765734717, 0.90317089285859276, 133355),
#  (3.5036848414966562, -5.5433160727883948, 1.5726062019075664, 155576),
#  (4.471794636530217, -5.1787715438982511, 1.7302618124454807, 133810),
#  (5.4672199502553944, -5.3107402957977339, 1.120651784035323, 134212),
#  (7.9505173885107769, 49.56744039518594, 1.577229523494649, 76316),
#  (8.068295481456758, 5.1138252984422969, 1.7270931129969085, 134821),
#  (8.379158233403972, 24.296965860588081, 1.7215329767335261, 64342),
#  (8.6729733079670268, 23.539670956002109, 1.6080315732822641, 156839),
#  (8.766539792883103, 12.619871775393978, 1.7531963147204392, 156881),
#  (9.7009126917882718, 0.33645158509557199, 0.86509230049305774, 32),
#  (10.867741930028284, 10.1483165697808, 1.1485269606809001, 158901),
#  (11.049906186582712, -16.28933830817251, 1.693440635179337, 138634),
#  (11.182465963722047, 53.387833911735683, 1.2266148565205843, 41075),
#  (11.305924256048563, 45.748192172576275, 1.0400102790249797, 159593),
#  (11.417348834934497, -9.7953477079106239, 0.80188275759163352, 159789),
#  (11.4697285343139, 25.661164506455204, 1.1508563640921854, 139467),
#  (147100, 248.08729887487408, 19.826429935613607, 296.76097131061289, '39.2'),
#  (166313, 234.13201128189172, 16.607773796114294, 242.01191185548487, '50.5'),
#  (142509, 193.66923774986822, 28.938659048093044, 315.04871881777757, '88.1'),
#  (144045, 208.50110045509271, -7.9306647364415319, 331.26231108808196, '51.8'),
#  (146210, 232.69219084902602, -2.8294945768813164, 324.40531366257312, '41.3'),
#  (150440, 345.01499538374668, 15.980232808317528, 263.6680968991966, '-39.1'),
#  (140594, 180.09842900981425, -1.100078021849052, 200.62394590876298, '59.2')]

# %%
[hi.sdss_environs_query(True) for hi in decentoptions];
# Out:
# File catalogs/NSA140895_sdss.dat exists - not downloading anything.
# File catalogs/NSA147100_sdss.dat exists - not downloading anything.
# File catalogs/NSA166313_sdss.dat exists - not downloading anything.
# File catalogs/NSA142509_sdss.dat exists - not downloading anything.
# File catalogs/NSA144045_sdss.dat exists - not downloading anything.
# File catalogs/NSA146210_sdss.dat exists - not downloading anything.
# File catalogs/NSA150440_sdss.dat exists - not downloading anything.
# File catalogs/DLG6_sdss.dat exists - not downloading anything.

# %%
ntarg21 = [len(targeting.select_targets(hi,faintlimit=21,outercutrad=300)) for hi in decentoptions]
ntarg21p5 = [len(targeting.select_targets(hi,faintlimit=21.5,outercutrad=300)) for hi in decentoptions]
ntarg22 = [len(targeting.select_targets(hi,faintlimit=22,outercutrad=300)) for hi in decentoptions]
print 'NSA#:',[hi.nsaid for hi in decentoptions]
print 'r<22:',ntarg22
print 'nconfigs for r<22',[n/200 for n in ntarg22]
print 'r<21.5:',ntarg21p5
print 'nconfigs for r<21.5',[n/200 for n in ntarg21p5]
print 'r<21:',ntarg21
print 'nconfigs for r<21',[n/200 for n in ntarg21]
# Out:
# WARNING: In the next major release of astropy (0.3), the order of function
# arguments for creating a Column will change.  Currently the order is
# Column(name, data, ...), but in 0.3 and later it will be
# Column(data, name, ...).  This is consistent with Table and NumPy.
#
# In order to use the same code for Astropy 0.2 and 0.3, column objects
# should be created using named keyword arguments for data and name, e.g.:
# Column(name='a', data=[1, 2]). [astropy.table.table]
# Found host
#  DLG6 in GAMA!
# Found host
#  DLG6 in GAMA!
# Found host
#  DLG6 in GAMA!
# NSA#:
#  [140895, 147100, 166313, 142509, 144045, 146210, 150440, 140594]
# r<22: [6606, 9862, 13146, 7604, 7475, 4490, 11126, 19674]
# nconfigs for r<22 [33.03, 49.31, 65.73, 38.02, 37.375, 22.45, 55.63, 98.37]
# r<21.5: [4320, 6477, 8499, 4990, 4978, 2862, 7446, 12849]
# nconfigs for r<21.5 [21.6, 32.385, 42.495, 24.95, 24.89, 14.31, 37.23, 64.245]
# r<21: [2570, 3937, 5135, 3108, 3097, 1690, 4706, 7801]
# nconfigs for r<21 [12.85, 19.685, 25.675, 15.54, 15.485, 8.45, 23.53, 39.005]

# %%
bestoption = decentoptions[[o.nsaid for o in decentoptions].index(147100)]

# %%
print len(targeting.select_targets(bestoption,faintlimit=21,outercutrad=300))
print len(targeting.select_targets(bestoption,faintlimit=21,outercutrad=300,removegalsathighz=False))
len(targeting.select_targets(bestoption,faintlimit=21,outercutrad=300,removegalsathighz=False)) - len(targeting.select_targets(bestoption,faintlimit=21,outercutrad=300))
# Out:
# 3937
# 4064
# 127

# %% [markdown]
# ## Generate for "best" option

# %%
reload(targeting)
reload(mmthecto)
# Out:
# <module 'mmthecto' from 'mmthecto.py'>

# %%
catfn = 'mmthecto/NSA{0}.cat'.format(bestoption.nsaid)
tab=mmthecto.make_catalog(bestoption,fnout=catfn,repeatflux=20,removegalsathighz=False, inclspecqsos=True, removespecstars=False)
# Out:
# Found
# 30 QSO candidates
# Found
#  4104 targets
# Found
#  61 Flux stars
# Found 172 guide stars

# %%
#
msk = (tab['rank']=='1')
tabm = tab[msk]
targeting.sampled_imagelist(tabm['ra'],tabm['dec'],names=tabm['object'],n=200);

# %%
tabm = tab[tab['rank']=='3']
targeting.sampled_imagelist(tabm['ra'],tabm['dec'],names=tabm['object'],n=200);

# %% [raw]
# Generated 6 fields using xfitfibs on turtle and then sent the NSA147100.cfg back here

# %%
cfg = ascii.read('mmthecto/NSA147100.cfg')
# Out:
# ---------------------------------------------------------------------------
# InconsistentTableError                    Traceback (most recent call last)
# <ipython-input-13-1f06688aaf42> in <module>()
# ----> 1 cfg = ascii.read('mmthecto/NSA147100.cfg')
#
# /Users/erik/.virtualenvs/astropy/lib/python2.7/site-packages/astropy-0.2-py2.7-macosx-10.8-x86_64.egg/astropy/io/ascii/ui.pyc in read(table, guess, **kwargs)
#     126         guess = _GUESS
#     127     if guess:
# --> 128         dat = _guess(table, new_kwargs)
#     129     else:
#     130         reader = get_reader(**new_kwargs)
#
# /Users/erik/.virtualenvs/astropy/lib/python2.7/site-packages/astropy-0.2-py2.7-macosx-10.8-x86_64.egg/astropy/io/ascii/ui.pyc in _guess(table, read_kwargs)
#     202             lines.append('ERROR: Unable to guess table for with the guesses listed above.')
#     203             lines.append('Check the table and try with guess=False and appropriate arguments to read()')
# --> 204             raise core.InconsistentTableError('\n'.join(lines))
#     205
#     206 def _get_guess_kwargs_list():
#
# InconsistentTableError:
# ERROR: Unable to guess table for with the guesses listed below:
# Reader:Basic
# Reader:Rdb
# Reader:Tab
# Reader:Cds
# Reader:Daophot
# Reader:SExtractor
# Reader:Ipac
# Reader:Latex
# Reader:AASTex
# Reader:CommentedHeader delimiter: '|' quotechar: '"'
# Reader:CommentedHeader delimiter: '|' quotechar: "'"
# Reader:CommentedHeader delimiter: ',' quotechar: '"'
# Reader:CommentedHeader delimiter: ',' quotechar: "'"
# Reader:CommentedHeader delimiter: ' ' quotechar: '"'
# Reader:CommentedHeader delimiter: ' ' quotechar: "'"
# Reader:CommentedHeader delimiter: '\\s' quotechar: '"'
# Reader:CommentedHeader delimiter: '\\s' quotechar: "'"
# Reader:Basic delimiter: '|' quotechar: '"'
# Reader:Basic delimiter: '|' quotechar: "'"
# Reader:Basic delimiter: ',' quotechar: '"'
# Reader:Basic delimiter: ',' quotechar: "'"
# Reader:Basic delimiter: ' ' quotechar: '"'
# Reader:Basic delimiter: ' ' quotechar: "'"
# Reader:Basic delimiter: '\\s' quotechar: '"'
# Reader:Basic delimiter: '\\s' quotechar: "'"
# Reader:NoHeader delimiter: '|' quotechar: '"'
# Reader:NoHeader delimiter: '|' quotechar: "'"
# Reader:NoHeader delimiter: ',' quotechar: '"'
# Reader:NoHeader delimiter: ',' quotechar: "'"
# Reader:NoHeader delimiter: ' ' quotechar: '"'
# Reader:NoHeader delimiter: ' ' quotechar: "'"
# Reader:NoHeader delimiter: '\\s' quotechar: '"'
# Reader:NoHeader delimiter: '\\s' quotechar: "'"
# Reader:Basic
# ERROR: Unable to guess table for with the guesses listed above.
# Check the table and try with guess=False and appropriate arguments to read()
# ERROR: InconsistentTableError:
# ERROR: Unable to guess table for with the guesses listed below:
# Reader:Basic
# Reader:Rdb
# Reader:Tab
# Reader:Cds
# Reader:Daophot
# Reader:SExtractor
# Reader:Ipac
# Reader:Latex
# Reader:AASTex
# Reader:CommentedHeader delimiter: '|' quotechar: '"'
# Reader:CommentedHeader delimiter: '|' quotechar: "'"
# Reader:CommentedHeader delimiter: ',' quotechar: '"'
# Reader:CommentedHeader delimiter: ',' quotechar: "'"
# Reader:CommentedHeader delimiter: ' ' quotechar: '"'
# Reader:CommentedHeader delimiter: ' ' quotechar: "'"
# Reader:CommentedHeader delimiter: '\\s' quotechar: '"'
# Reader:CommentedHeader delimiter: '\\s' quotechar: "'"
# Reader:Basic delimiter: '|' quotechar: '"'
# Reader:Basic delimiter: '|' quotechar: "'"
# Reader:Basic delimiter: ',' quotechar: '"'
# Reader:Basic delimiter: ',' quotechar: "'"
# Reader:Basic delimiter: ' ' quotechar: '"'
# Reader:Basic delimiter: ' ' quotechar: "'"
# Reader:Basic delimiter: '\\s' quotechar: '"'
# Reader:Basic delimiter: '\\s' quotechar: "'"
# Reader:NoHeader delimiter: '|' quotechar: '"'
# Reader:NoHeader delimiter: '|' quotechar: "'"
# Reader:NoHeader delimiter: ',' quotechar: '"'
# Reader:NoHeader delimiter: ',' quotechar: "'"
# Reader:NoHeader delimiter: ' ' quotechar: '"'
# Reader:NoHeader delimiter: ' ' quotechar: "'"
# Reader:NoHeader delimiter: '\\s' quotechar: '"'
# Reader:NoHeader delimiter: '\\s' quotechar: "'"
# Reader:Basic
# ERROR: Unable to guess table for with the guesses listed above.
# Check the table and try with guess=False and appropriate arguments to read() [astropy.io.ascii.ui]

# %% [markdown]
# ## Early Tests On A Generated CFG

# %%
t=targeting.select_targets(decentoptions[0],faintlimit=21,outercutrad=300)

# %%
mmthecto.make_catalog(decentoptions[0],fnout='mmthecto/test.cat')
# Out:
# 'ra\tdec\tobject\trank\ttype\tmag\n--\t---\t------\t----\t----\t---\n12:11:53.121\t24:07:30.291\tNSA140895\t2\tTARGET\t12.49\n12:12:11.185\t24:27:41.293\t1237667446729081005\t3\tTARGET\t18.82\n12:13:08.371\t23:51:38.639\t1237667910055690640\t3\tTARGET\t20.35\n12:11:37.119\t23:42:03.935\t1237667736655495683\t3
10:44.574\t24:11:52.801\t1237667910592299648\t3\tTARGET\t19.84\n12:09:55.213\t24:05:13.381\t1237667446192013616\t3\tTARGET\t19.83\n12:13:04.934\t24:01:31.192\t1237667446192276111\t3\tTARGET\t20.20\n12:12:27.636\t24:11:09.833\t1237667910592496079\t3\tTARGET\t19.52\n12:12:40.406\t24:13:16.977\t1237667910592496203\t3\tTARGET\t20.34\n12:11:26.916\t24:06:04.710\t1237667446192144857\t3\tTARGET\t20.50\n12:12:28.301\t24:07:33.996\t1237667446192210249\t3\tTARGET\t20.15\n12:12:56.100\t23:45:21.229\t1237667910055690344\t3\tTARGET\t17.87\n12:12:53.213\t24:22:44.325\t1237667446729146527\t3\tTARGET\t18.97\n12:13:49.658\t24:08:52.936\t1237667446192406997\t3\tTARGET\t20.80\n12:10:54.917\t24:04:33.906\t1237667446192079354\t3\tTARGET\t20.33\n12:12:42.515\t24:09:45.147\t1237667910592496227\t3\tTARGET\t20.91\n12:12:29.300\t23:46:32.109\t1237667910055624947\t3\tTARGET\t19.99\n12:11:58.011\t24:10:57.225\t1237667910592430215\t3\tTARGET\t18.60\n12:13:05.748\t24:12:41.684\t1237667910592561357\t3\tTARGET\t20.55\n12:10:43.543\t23:46:08.531\t1237667910055428310\t3\tTARGET\t20.94\n12:11:44.560\t24:26:59.583\t1237667446729015546\t3\tTARGET\t18.72\n12:13:28.109\t24:10:26.583\t1237667910592561399\t3\tTAR ...

# %%
#ran xfitfibs on turtle to create some test config files - entries is 
testcfg = ascii.read('mmthecto/test.cfg.entries')
ras = array([coords.Angle(i,'hr').degrees for i in testcfg['ra']])
decs = array([coords.Angle(i,'deg').degrees for i in testcfg['dec']])
testcfg.dtype.names
# Out:
# ('fiber', 'ra', 'dec', 'platex', 'platey', 'target', 'rank')

# %%
msk = testcfg['rank']==1 # flux cal targets
targeting.sampled_imagelist(ras[msk],decs[msk],names=testcfg['target'][msk])
# Out:
# 'name ra dec\n2581 182.69266625 24.4633847222\n2580 182.572174167 24.4365025\n2573 182.856430833 24.0977363889\n2582 182.491965417 23.9500255556\n2572 182.965750833 24.0593491667\n2588 183.182845 24.0044116667\n2587 183.168754583 24.1395569444\n2578 183.351674167 24.2893561111\n2577 183.141575 24.4581452778\n2594 182.7832175 24.2191505556\n2575 182.635445417 24.2406808333\n2584 182.54397875 23.8432636111\n2586 182.817678333 23.9865569444\n2592 182.562389167 23.7603511111\n2574 182.871651667 24.0254038889\n2576 183.401641667 24.0880852778\n2593 182.990255417 23.8573436111\n2590 183.216433333 23.6026744444\n2579 183.471164583 24.0512122222\n2589 183.500733333 24.0967902778'

# %%
msk = testcfg['rank']==2 # host center target
targeting.sampled_imagelist(ras[msk],decs[msk],names=testcfg['target'][msk])
# Out:
# 'name ra dec\n1 182.971344167 24.12508'

# %%
msk = testcfg['rank']==3 # sat targets
targeting.sampled_imagelist(ras[msk],decs[msk],n=100,names=testcfg['target'][msk])
# Out:
